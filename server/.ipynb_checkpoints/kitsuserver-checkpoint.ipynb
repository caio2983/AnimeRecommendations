# %%
from fastapi.middleware.cors import CORSMiddleware
from fastapi import FastAPI, Request
import requests

# %run kitsuclassifier.ipynb
# Out:
# [{'slug': 'middle-school', 'title': 'Middle School'}, {'slug': 'cycling', 'title': 'Cycling'}, {'slug': 'elementary-school', 'title': 'Elementary School'}, {'slug': 'mermaid', 'title': 'Mermaid'}, {'slug': 'android', 'title': 'Android'}, {'slug': 'all-girls-school', 'title': 'All Girls School'}, {'slug': 'vampire', 'title': 'Vampire'}, {'slug': 'wrestling', 'title': 'Wrestling'}, {'slug': 'samurai', 'title': 'Samurai'}, {'slug': 'elf', 'title': 'Elf'}, {'slug': 'pirate', 'title': 'Pirate'}, {'slug': 'bishounen', 'title': 'Bishounen'}, {'slug': 'tentacle', 'title': 'Tentacle'}, {'slug': 'boxing', 'title': 'Boxing'}, {'slug': 'musical-band', 'title': 'Musical Band'}, {'slug': 'cooking', 'title': 'Cooking'}, {'slug': 'air-force', 'title': 'Air Force'}, {'slug': 'bounty-hunter', 'title': 'Bounty Hunter'}, {'slug': 'high-school', 'title': 'High School'}, {'slug': 'delinquent', 'title': 'Delinquent'}, {'slug': 'maid', 'title': 'Maid'}, {'slug': 'magic', 'title': 'Magic'}, {'slug': 'cyborg'
# ...

# %%
# !uvicorn kitsuserver:app --reload

app = FastAPI()

app.add_middleware(
    CORSMiddleware,
    allow_origins=['http://localhost:4200'],  
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"], 
)

# Searches for the anime's category, calls the model
@app.post("/recommend")
def recommend(id):
    print("testeeee")
    
    r = requests.get(f'https://kitsu.io/api/edge/anime/{id}/categories')
    data = r.json()
    categories = []
    for category in data["data"][:3]:
        categories.append({'slug' : category["attributes"]["slug"],
            'title' :category["attributes"]["title"]})

    animes = []

    for category in categories:
        animes += get_all_animes_per_categorie(category["slug"])
        
    return animes
